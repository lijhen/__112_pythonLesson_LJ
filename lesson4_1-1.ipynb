# %%
import requests
url='https://tcgbusfs.blob.core.windows.net/dotapp/youbike/v2/youbike_immediate.json' #網路上查詢資料 open API
response = requests.request('get',url)
if response.status_code == 200:
    print("連線成功")
    all_data = response.json()
    print(type(all_data))
else:
    print(f"連線失敗:{response.status_code}")
# Out:
# 連線成功
# <class 'list'>

# %% [markdown]
# ## 通訊協定
# Get 獲取資料
#
#     http
#     requests：外部提供的module
#     requests.request(method, url, **)
#
# Post 送出
#
#     包在request裡面送出給server\
#
# json
#
#     純文字的資料格式
#
#     - json online viewer\
# csv xml json 線上傳遞資料最常使用的格式

# %% [markdown]
# $ git push-f\
# 強制更新送出

# %%
import pandas as pd

dataFrame = pd.DataFrame(data=all_data)
dataFrame
# Out:
#             sno                       sna  tot  sbi   sarea
# 0     500101001        YouBike2.0_捷運科技大樓站   28    5     大安區  \
# 1     500101002    YouBike2.0_復興南路二段273號前   21    2     大安區
# 2     500101003      YouBike2.0_國北教大實小東側門   16    4     大安區
# 3     500101004         YouBike2.0_和平公園東側   11    0     大安區
# 4     500101005      YouBike2.0_辛亥復興路口西北側   16    0     大安區
# ...         ...                       ...  ...  ...     ...
# 1276  500119087      YouBike2.0_臺大總圖書館西南側   30    3    臺大專區
# 1277  500119088        YouBike2.0_臺大黑森林西側   20    1    臺大專區
# 1278  500119089        YouBike2.0_臺大獸醫館南側   24    1    臺大專區
# 1279  500119090      YouBike2.0_臺大新體育館東南側   40    1    臺大專區
# 1280  500119091  YouBike2.0_臺大明達館北側(員工宿舍)   18    2  臺大公館校區
#
#                      mday       lat        lng             ar     sareaen
# 0     2023-06-02 20:30:43  25.02605  121.54360    復興南路二段235號前  Daan Dist.  \
# 1     2023-06-02 20:30:43  25.02565  121.54357   復興南路二段273號西側  Daan Dist.
# 2     2023-06-02 20:25:14  25.02429  121.54124    和平東路二段96巷7號  Daan Dist.
# 3     2023-06-02 20:25:04  25.02351  121.54282  和平東路二段118巷33號  Daan Dist.
# 4     2023-06-02 20:30:43  25.02153  121.54299     復興南路二段368號  Daan Dist.
# ...                   ...       ...        ...            ...         ...
# 1276  2023-06-02 20:29:14  25.01690  121.54031       臺大圖書館西南側    NTU Dist
# 1277  2023-06-02 20:30:44  25.01995  121.54347        臺大霖澤館南側    NTU Dist
# 1278  2023-06-02 20:28:14  25.01791  121.54242       臺大獸醫系館南側    NTU Dist
# 1279  2023-06-02 20:23:15  25.02112  121.53591        臺大體育館東側    NTU Dist
# 1280  2023-06-02 20:28:14  25.01816  121.54469       明達館北側前空地    NTU Dist
#
#                                                   snaen
# 0                  YouBike2.0_MRT Technology Bldg. Sta.  \
# 1              YouBike2.0_No.273， Sec. 2， Fuxing S. Rd.
# 2     YouBike2.0_NTUE Experiment Elementary School (...
# 3                         YouBike2.0_Heping Park (East)
# 4     YouBike2.0_Xinhai Fuxing Rd. Intersection (Nor...
# ...                                                 ...
# 1276             YouBike2.0_NTU Main Library(Southwest)
# 1277                  YouBike2.0_NTU Black Forest(West)
# 1278  YouBike2.0_NTU Dept. of Veterinary Medicine(So...
# 1279            YouBike2.0_NTU Sports Center(Southeast)
# 1280    YouBike2.0_NTU Ming - Da Hall (Staff Dormitory)
#
#                                          aren  bemp act        srcUpdateTime
# 0               No.235， Sec. 2， Fuxing S. Rd.    23   1  2023-06-02 20:31:34  \
# 1        No.273， Sec. 2， Fuxing S. Rd. (West)    19   1  2023-06-02 20:31:34
# 2         No. 7， Ln. 96， Sec. 2， Heping E. Rd    12   1  2023-06-02 20:31:34
# 3       No. 33， Ln. 118， Sec. 2， Heping E. Rd    11   1  2023-06-02 20:31:34
# 4              No. 368， Sec. 2， Fuxing S. Rd.    16   1  2023-06-02 20:31:34
# ...                                       ...   ...  ..                  ...
# 1276              NTU Main Library(Southwest)    27   1  2023-06-02 20:31:34
# 1277             NTU Tsai Lecture Hall(South)    19   1  2023-06-02 20:31:34
# 1278  NTU Dept. of Veterinary Medicine(South)    23   1  2023-06-02 20:31:34
# 1279                  NTU Sports Center(East)    39   1  2023-06-02 20:31:34
# 1280               NTU Ming - Da Hall (North)    16   1  2023-06-02 20:31:34
#
#                updateTime             infoTime    infoDate
# 0     2023-06-02 20:31:51  2023-06-02 20:30:43  2023-06-02
# 1     2023-06-02 20:31:51  2023-06-02 20:30:43  2023-06-02
# 2     2023-06-02 20:31:51  2023-06-02 20:25:14  2023-06-02
# 3     2023-06-02 20:31:51  2023-06-02 20:25:04  2023-06-02
# 4     2023-06-02 20:31:51  2023-06-02 20:30:43  2023-06-02
# ...                   ...                  ...         ...
# 1276  2023-06-02 20:31:51  2023-06-02 20:29:14  2023-06-02
# 1277  2023-06-02 20:31:51  2023-06-02 20:30:44  2023-06-02
# 1278  2023-06-02 20:31:51  2023-06-02 20:28:14  2023-06-02
# 1279  2023-06-02 20:31:51  2023-06-02 20:23:15  2023-06-02
# 1280  2023-06-02 20:31:51  2023-06-02 20:28:14  2023-06-02
#
# [1281 rows x 18 columns]

# %%
dataFrame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1281 entries, 0 to 1280
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   sno            1281 non-null   object
#  1   sna            1281 non-null   object
#  2   tot            1281 non-null   int64
#  3   sbi            1281 non-null   int64
#  4   sarea          1281 non-null   object
#  5   mday           1281 non-null   object
#  6   lat            1281 non-null   float64
#  7   lng            1281 non-null   float64
#  8   ar             1281 non-null   object
#  9   sareaen        1281 non-null   object
#  10  snaen          1281 non-null   object
#  11  aren           1281 non-null   object
#  12  bemp           1281 non-null   int64
#  13  act            1281 non-null   object
#  14  srcUpdateTime  1281 non-null   object
#  15  updateTime     1281 non-null   object
#  16  infoTime       1281 non-null   object
#  17  infoDate       1281 non-null   object
# dtypes: float64(2), int64(3), object(13)
# memory usage: 180.3+ KB

# %%
dataFrame = pd.DataFrame(data=all_data,columns=['sna','tot']) #篩選欄位
dataFrame
# Out:
#                            sna  tot
# 0           YouBike2.0_捷運科技大樓站   28
# 1       YouBike2.0_復興南路二段273號前   21
# 2         YouBike2.0_國北教大實小東側門   16
# 3            YouBike2.0_和平公園東側   11
# 4         YouBike2.0_辛亥復興路口西北側   16
# ...                        ...  ...
# 1276      YouBike2.0_臺大總圖書館西南側   30
# 1277        YouBike2.0_臺大黑森林西側   20
# 1278        YouBike2.0_臺大獸醫館南側   24
# 1279      YouBike2.0_臺大新體育館東南側   40
# 1280  YouBike2.0_臺大明達館北側(員工宿舍)   18
#
# [1281 rows x 2 columns]
